# %%
import pandas as pd
import numpy as np
import warnings

def dataset_generation(sample_size=1000):
    np.random.seed(42)
    fertilizer = np.random.choice(['Organic', 'Synthetic'], size=sample_size)
    plant_height = np.random.normal(100, 8, size=sample_size)
    Number_of_leaves = np.random.normal(20, 4, size=sample_size)
    Leaf_width = np.random.normal(12, 2, size=sample_size)
    leaf_height = np.random.normal(15, 3, size=sample_size)
    root_length = np.random.normal(25, 9, size=sample_size)
    number_of_pods = np.random.normal(70, 8, size=sample_size)
    pod_length = np.random.normal(18, 5, size=sample_size)
    Yield = np.random.normal(70, 8, size=sample_size)
    
    data = pd.DataFrame({
        "Fertilizer": fertilizer,
        'Plant Height (cm)': plant_height,
        'Number of Leaves': Number_of_leaves,
        'Leaf Width (cm)': Leaf_width,
        'Leaf Height (cm)': leaf_height,
        'Root Length (cm)': root_length,
        'Number of Pods': number_of_pods,
        'Pod Length (cm)': pod_length,
        'Yield (kg/ha)': Yield,
        
    })
    return data
    
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df = dataset_generation(sample_size=1000)
display(df.head(10))
# Out:
#   Fertilizer  Plant Height (cm)  Number of Leaves  Leaf Width (cm)  \
# 0    Organic             102.73             25.21            11.54
# 1  Synthetic             115.01             26.25            10.15
# 2    Organic             107.60             20.13            13.78
# 3    Organic              95.38             16.99            14.07
# 4    Organic              92.81             21.84             8.31
# 5  Synthetic             103.94             17.29            10.14
# 6    Organic              89.44             28.05             9.01
# 7    Organic             114.65             20.55            10.70
# 8    Organic             109.44             18.54            11.83
# 9  Synthetic              96.25             20.74             9.10
#
#    Leaf Height (cm)  Root Length (cm)  Number of Pods  Pod Length (cm)  \
# 0             12.55             18.82           80.81            17.88
# 1             15.23             12.11           57.90            10.89
# 2             17.58             26.31           59.35            22.21
# 3             15.42             30.27           52.58            21.77
# 4             10.27             29.63           64.40             8.29
# 5             12.59             32.38           71.29            17.98
# 6             14.78             27.92           70.82            10.05
# 7             14.77             20.21           71.19            14.68
# 8             20.92             32.56           58.71            13.49
# 9             10.84             12.78           76.43            22.05
#
#    Yield (kg/ha)
# 0          67.47
# 1          72.51
# 2          73.51
# 3          76.67
# 4          80.26
# 5          70.62
# 6          59.54
# 7          67.24
# 8          70.35
# 9          55.31
